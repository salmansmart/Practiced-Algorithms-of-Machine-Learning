# %%
import re

# %%
text = "Welcome to the world of Python. Welcome you all."
text1 = "Hello all, Welcome you to this show"

# %%
result=re.compile('Welcome')

# %%
result
# Out:
# re.compile(r'Welcome', re.UNICODE)

# %%
ans=result.search(text)
ans
# Out:
# <re.Match object; span=(0, 7), match='Welcome'>

# %%
x=result.findall(text)

print(len(x),'times',x)
# Out:
# 2 times ['Welcome', 'Welcome']

# %%
a = 'This is an example for regular expression'
result = re.search('example',a)
result.start()
print('Start Index:', result.start())
# Out:
# Start Index: 11

# %%
a = 'This is an example for regular expression'

result = re.search('example',a)

# result -> match object

# find the start index of a string
result.start()
print('Start Index:', result.start())

# find the end index of that string
print('End Index:', result.end())

# find the start and end index of that string
print('End Index:', result.span())
# Out:
# Start Index: 11
# End Index: 18
# End Index: (11, 18)

# %%
x='hi this is salman'
opt=re.search('salman',x)
print(opt.start())
print(opt.end())
print(opt.span())
# Out:
# 11
# 17
# (11, 17)

# %%
find=re.findall('salman',x)
find
# Out:
# ['salman']

# %%
sen='love is beautiful.'
a=re.search(r'^love',sen)
a
# Out:
# <re.Match object; span=(0, 4), match='love'>

# %%
sen='love is beautiful'
c=re.search(r'beautiful$',sen)
print(c)

result=re.search('beautiful',sen)
result.span()
# Out:
# <re.Match object; span=(8, 17), match='beautiful'>
# (8, 17)

# %%
a = "Example: This is best example for Regular Expression"
b=re.findall('[Ee]xample',a)
b
# Out:
# ['Example', 'example']

# %%
text = 'The cyber security has become one of the most important ascept of the business. \
$550 million has been invested research. 12.45.65.78 is one the most spammed inject ips. \
ask@web.com. $600 million wasted. save safe.'

a=re.search(r'cyber',text)
b=re.findall(r'[a-z A-Z]',text)
c=re.findall(r'[0-9]',text)
print(a)
print(b)
print(c)
# Out:
# <re.Match object; span=(4, 9), match='cyber'>
# ['T', 'h', 'e', ' ', 'c', 'y', 'b', 'e', 'r', ' ', 's', 'e', 'c', 'u', 'r', 'i', 't', 'y', ' ', 'h', 'a', 's', ' ', 'b', 'e', 'c', 'o', 'm', 'e', ' ', 'o', 'n', 'e', ' ', 'o', 'f', ' ', 't', 'h', 'e', ' ', 'm', 'o', 's', 't', ' ', 'i', 'm', 'p', 'o', 'r', 't', 'a', 'n', 't', ' ', 'a', 's', 'c', 'e', 'p', 't', ' ', 'o', 'f', ' ', 't', 'h', 'e', ' ', 'b', 'u', 's', 'i', 'n', 'e', 's', 's', ' ', ' ', 'm', 'i', 'l', 'l', 'i', 'o', 'n', ' ', 'h', 'a', 's', ' ', 'b', 'e', 'e', 'n', ' ', 'i', 'n', 'v', 'e', 's', 't', 'e', 'd', ' ', 'r', 'e', 's', 'e', 'a', 'r', 'c', 'h', ' ', ' ', 'i', 's', ' ', 'o', 'n', 'e', ' ', 't', 'h', 'e', ' ', 'm', 'o', 's', 't', ' ', 's', 'p', 'a', 'm', 'm', 'e', 'd', ' ', 'i', 'n', 'j', 'e', 'c', 't', ' ', 'i', 'p', 's', ' ', 'a', 's', 'k', 'w', 'e', 'b', 'c', 'o', 'm', ' ', ' ', 'm', 'i', 'l', 'l', 'i', 'o', 'n', ' ', 'w', 'a', 's', 't', 'e', 'd', ' ', 's', 'a', 'v', 'e', ' ', 's', 'a', 'f', 'e']
# ['5', '5', '0', '1', '2', '4', '5', '6', '5', '7', '8', '6', '0', '0']

# %%
a = "Hello Harish, how are you? Are you coming to the party?"
print(re.findall(r'H[^e]',a))
# Out:
# ['Ha']

# %%
sen
# Out:
# 'love is beautiful'

# %%
print(re.search(r'be..t.f..',sen))
print(re.findall(r'be..t.f..',sen))
# Out:
# <re.Match object; span=(8, 17), match='beautiful'>
# ['beautiful']

# %%
se = "to spell humour, some use humour and some use humor"
print(re.findall(r'humou?r',se))
# Out:
# ['humour', 'humour', 'humor']

# %%
text
# Out:
# 'The cyber security has become one of the most important ascept of the business. $550 million has been invested research. 12.45.65.78 is one the most spammed inject ips. ask@web.com. $600 million wasted. save safe.'

# %%
print(re.findall(r'sa.e',text))
# Out:
# ['save', 'safe']

# %%
comp=re.compile('\d')
comp1=re.compile('\d+')

# %%
print(comp.findall(text))
# Out:
# ['5', '5', '0', '1', '2', '4', '5', '6', '5', '7', '8', '6', '0', '0']

# %%
print(comp1.findall(text))
# Out:
# ['550', '12', '45', '65', '78', '600']

# %%
print(re.findall('\d+',text))
# Out:
# ['550', '12', '45', '65', '78', '600']

# %%
print(re.findall('safe|saze',text))
# Out:
# ['safe']

# %%
re.findall('[a-z]+',text)
# Out:
# ['he',
#  'cyber',
#  'security',
#  'has',
#  'become',
#  'one',
#  'of',
#  'the',
#  'most',
#  'important',
#  'ascept',
#  'of',
#  'the',
#  'business',
#  'million',
#  'has',
#  'been',
#  'invested',
#  'research',
#  'is',
#  'one',
#  'the',
#  'most',
#  'spammed',
#  'inject',
#  'ips',
#  'ask',
#  'web',
#  'com',
#  'million',
#  'wasted',
#  'save',
#  'safe']

# %%
re.findall('[a-z 0-9]+@+[a-z 0-9]+.com',text)
# Out:
# [' ask@web.com']

# %%
print(re.findall('\w',text))
# Out:
# ['T', 'h', 'e', 'c', 'y', 'b', 'e', 'r', 's', 'e', 'c', 'u', 'r', 'i', 't', 'y', 'h', 'a', 's', 'b', 'e', 'c', 'o', 'm', 'e', 'o', 'n', 'e', 'o', 'f', 't', 'h', 'e', 'm', 'o', 's', 't', 'i', 'm', 'p', 'o', 'r', 't', 'a', 'n', 't', 'a', 's', 'c', 'e', 'p', 't', 'o', 'f', 't', 'h', 'e', 'b', 'u', 's', 'i', 'n', 'e', 's', 's', '5', '5', '0', 'm', 'i', 'l', 'l', 'i', 'o', 'n', 'h', 'a', 's', 'b', 'e', 'e', 'n', 'i', 'n', 'v', 'e', 's', 't', 'e', 'd', 'r', 'e', 's', 'e', 'a', 'r', 'c', 'h', '1', '2', '4', '5', '6', '5', '7', '8', 'i', 's', 'o', 'n', 'e', 't', 'h', 'e', 'm', 'o', 's', 't', 's', 'p', 'a', 'm', 'm', 'e', 'd', 'i', 'n', 'j', 'e', 'c', 't', 'i', 'p', 's', 'a', 's', 'k', 'w', 'e', 'b', 'c', 'o', 'm', '6', '0', '0', 'm', 'i', 'l', 'l', 'i', 'o', 'n', 'w', 'a', 's', 't', 'e', 'd', 's', 'a', 'v', 'e', 's', 'a', 'f', 'e']

# %%
print(re.findall('\w+',text))
# Out:
# ['The', 'cyber', 'security', 'has', 'become', 'one', 'of', 'the', 'most', 'important', 'ascept', 'of', 'the', 'business', '550', 'million', 'has', 'been', 'invested', 'research', '12', '45', '65', '78', 'is', 'one', 'the', 'most', 'spammed', 'inject', 'ips', 'ask', 'web', 'com', '600', 'million', 'wasted', 'save', 'safe']

# %%
print(re.findall('\W',text))
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '.', ' ', '$', ' ', ' ', ' ', ' ', ' ', '.', ' ', '.', '.', '.', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '.', ' ', '@', '.', '.', ' ', '$', ' ', ' ', '.', ' ', ' ', '.']

# %%
print(re.findall('\W+',text))
# Out:
# [' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. $', ' ', ' ', ' ', ' ', ' ', '. ', '.', '.', '.', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '. ', '@', '.', '. $', ' ', ' ', '. ', ' ', '.']

# %%
print(re.split('\d+', 'Complete it on or before 15th Jan 2023. The exam will be on 25th Jan 2023'))
# Out:
# ['Complete it on or before ', 'th Jan ', '. The exam will be on ', 'th Jan ', '']

# %%
print(re.split("\W+",'Neeta, Raghu and Harish are playing'))
# Out:
# ['Neeta', 'Raghu', 'and', 'Harish', 'are', 'playing']

# %%
print(re.split('[e-n E-N]+','Neeta, Raghu and Harish are playing'))
# Out:
# ['', 'ta,', 'Ra', 'u', 'a', 'd', 'ar', 's', 'ar', 'p', 'ay', '']

# %%
print(re.sub('am','#$','Ramya came to the CAMPUS yesterday',flags=re.IGNORECASE))
# Out:
# R#$ya c#$e to the C#$PUS yesterday

# %%
print(re.subn('am','#$','Ramya came to the CAMPUS yesterday',flags=re.IGNORECASE))
# Out:
# ('R#$ya c#$e to the C#$PUS yesterday', 3)

# %%
print(re.escape(text))
# Out:
# The\ cyber\ security\ has\ become\ one\ of\ the\ most\ important\ ascept\ of\ the\ business\.\ \$550\ million\ has\ been\ invested\ research\.\ 12\.45\.65\.78\ is\ one\ the\ most\ spammed\ inject\ ips\.\ ask@web\.com\.\ \$600\ million\ wasted\.\ save\ safe\.

# %%
sen = "Look into this problem"
a=re.search(r'\D{3} t',sen)
print(a.group())
# Out:
# nto t

# %%
import re

sen = "Engagement is on April 5 and wedding is on May 26"
a = re.search(r"([a-zA-Z]+)\s(\d+)", sen)

print(a.group())   # Full matched text (e.g., "April 5")
print(a.group(1))  # First group: "April"
print(a.group(2))  # Second group: "5"
# Out:
# April 5
# April
# 5
